# %%
# #This Notebook is for NovelAI with Stable-Diffusion version and 7G animefull-final-latest model used.

# %%
# #安装依赖（联网版，优点是可以同步官方更新，缺点是不稳定，可能同步官方为及时修复的bug）

# #Test GPU 测试GPU
# !nvidia-smi

# #Download SD-WebUi 下载SD-WebUi
#　%cd /kaggle/working/
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
#　!cp -r /kaggle/input/stablediffusionwebui/stable-diffusion-webui-master /kaggle/working/stable-diffusion-webui

    
# #Make folder for models  新建模型目录
# !mkdir -p /kaggle/working/stable-diffusion-webui/models/Stable-diffusion /kaggle/working/stable-diffusion-webui/models/hypernetworks 
# %cd /kaggle/working/stable-diffusion-webui/models/Stable-diffusion

#　!apt install -y aria2
# # Models
# # 7G animefull-final-latest (optional)
# !aria2c -d /kaggle/working/stable-diffusion-webui https://cloudflare-ipfs.com/ipfs/bafybeiav3j7npiuewbel3mi32l3sidgkw54kuleosbhxmdvddbnvtfi7yu/config.yaml
# #!aria2c https://pub-2fdef7a2969f43289c42ac5ae3412fd4.r2.dev/animefull-latest.ckpt
# #!aria2c -d /kaggle/working/stable-diffusion-webui/models/Stable-diffusion https://raw.githubusercontent.com/Stability-AI/stablediffusion/main/configs/stable-diffusion/v2-inference-v.yaml

# # Install embeddings (optional)
# !aria2c https://cloudflare-ipfs.com/ipfs/bafybeie3hdjchxs5tz4n75bos53nhcklslguxchdurc2ynrzcfv2kwyklu/embeddings.tar
# !tar xvf embeddings.tar -C /kaggle/working/stable-diffusion-webui/embeddings && rm -rf embeddings.tar

# # Install VAE Weights (optional)
# #!aria2c -o animefull-final-pruned.vae.pt https://cloudflare-ipfs.com/ipfs/bafybeiccldswdd3wvg57jhclcq53lvsc6gizasiblwayvhlv6eq4wow7wu/animevae.pt 
# #!ln -s animefull-final-pruned.vae.pt animefull-final-latest.vae.pt

# # Install hypernetwork （optional)
# !aria2c https://cloudflare-ipfs.com/ipfs/bafybeiduanx2b3mcvxlwr66igcwnpfmk3nc3qgxlpwh6oq6m6pxii3f77e/_modules.tar  
# !tar xvf _modules.tar -C /kaggle/working/stable-diffusion-webui/models/hypernetworks && rm -rf _modules.tar

# %%
#安装依赖（复制input版，优点是稳定，确定是无法同步官网更新）
# !cp -r /kaggle/input/stablediffusionwebui20230125/stable-diffusion-webui /kaggle/working/stable-diffusion-webui/

# %%
#复制训练好的模型copy the pt file to embeddings
import os,shutil
try:
    ptlist = os.listdir('/kaggle/input/trainedpt2/')
    print(ptlist)
    for i in ptlist:
        shutil.copy('/kaggle/input/trainedpt2/'+i,'/kaggle/working/stable-diffusion-webui/embeddings/'+i)
except:
    pass

#训练备用：
#新建用于存放预处理图片的文件夹 create a folder to save the preprocessed data
# !mkdir -p /kaggle/working/preprocessed

# %%
#安装插件
# %cd /kaggle/working/stable-diffusion-webui/extensions
# !git clone https://github.com/dtlnor/stable-diffusion-webui-localization-zh_CN
# !git clone https://github.com/DominikDoom/a1111-sd-webui-tagcomplete
# !git clone https://github.com/yfszzx/stable-diffusion-webui-images-browser
# !git clone https://github.com/zero01101/openOutpaint-webUI-extension
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks
#!git clone https://github.com/7eu7d7/DreamArtist-sd-webui-extension
#!git clone https://github.com/d8ahazard/sd_dreambooth_extension
#!git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui-aesthetic-gradients
# !cp -r /kaggle/input/tagcomplete3w2cn/tagcomplete-3w2-cn /kaggle/working/stable-diffusion-webui/extensions/tagcomplete-3w2-cn/
# !cp -r /kaggle/input/tagcomplete3w2cn/maple-from-fall-and-flower/maple-from-fall-and-flower/scripts /kaggle/working/stable-diffusion-webui/extensions/maple-from-fall-and-flower
# Out:
# /kaggle/working/stable-diffusion-webui/extensions
# fatal: destination path 'stable-diffusion-webui-localization-zh_CN' already exists and is not an empty directory.
# fatal: destination path 'a1111-sd-webui-tagcomplete' already exists and is not an empty directory.
# fatal: destination path 'stable-diffusion-webui-images-browser' already exists and is not an empty directory.
# fatal: destination path 'openOutpaint-webUI-extension' already exists and is not an empty directory.
# fatal: destination path 'sd-webui-additional-networks' already exists and is not an empty directory.

# %%
#调整设置
# !cp -r /kaggle/input/sddefaultsetting/config.json /kaggle/working/stable-diffusion-webui/config.json
# !cp -r /kaggle/input/sddefaultsetting/ui-config.json /kaggle/working/stable-diffusion-webui/ui-config.json
# !cp -r /kaggle/input/stylefile/styles.csv /kaggle/working/stable-diffusion-webui/styles.csv
import os
import re
with open('/kaggle/working/stable-diffusion-webui/requirements.txt','r') as f:
    req = f.read()
req = re.sub('gradio==.*?\n','gradio==3.13\n',req)
with open('/kaggle/working/stable-diffusion-webui/requirements.txt','w') as f:
    f.write(req)
with open('/kaggle/working/stable-diffusion-webui/requirements_versions.txt','r') as f:
    req = f.read()
req = re.sub('gradio==.*?\n','gradio==3.13\n',req)
with open('/kaggle/working/stable-diffusion-webui/requirements_versions.txt','w') as f:
    f.write(req)
# Out:
# cp: cannot stat '/kaggle/input/stylefile/styles.csv': No such file or directory

# %%
#复制lora模型
# !cp -r /kaggle/input/loramodels/ /kaggle/working/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora

#某不知名大佬上传的原神lora模型，3G多，默认不加载。如需加载，去掉井号
#!cp -r /kaggle/input/aaagen /kaggle/working/stable-diffusion-webui/extensions/sd-webui-additional-networks/models/lora

# %%
#最新切换模型方法
import re
import os
import shutil

def ChangeModel(modelPath):
    with open ('/kaggle/working/stable-diffusion-webui/modules/sd_models.py','r') as f:
        tt = f.read()
    tt = re.sub('model_dir = ".*?"','model_dir = "/kaggle/input/{}"'.format(modelPath),tt)
    with open ('/kaggle/working/stable-diffusion-webui/modules/sd_models.py','w') as f:
        f.write(tt)

#Select the model you like根据喜好选择模型
#Remove the # signal before the code if you want to run the model, and add the # symbol before the other
#在你想要使用的模型对应的代码前去掉#，其他模型的对应代码前加上#
chooseModel = ''

#二次元
#chooseModel='animefulllatestckpt'      #Model 1:7g animefull-final-latest
#chooseModel='animefullfinalpruned'     #Model 2:4g animefull-final-pruned
chooseModel='anythingv3'               #Model 3:7g Anything-v3.0
#chooseModel='momoko'                   #Model 4:momoko
#chooseModel='mignon'                   #Model 5:Mignon
#chooseModel='moxing'                   #Model 6:MomoCha&Mecha
#chooseModel='nicenice'                 #model 7:nice
#chooseModel='gamecg-9702'              #model 8:gamecg
#chooseModel='anythingmix3d'            #model 9:AnythingMix3D
#chooseModel='lansejuzi'                #model 10:蓝色橘子
#chooseModel='gfstyle2'                 #model 11:国风2版

#写实风
#chooseModel='stable-diffusion-1-5'     #Model 1:stable-diffusion 1.5
#chooseModel='stable-diffusion-2-768'   #Model 2:stable diffusion 2.0
#chooseModel='redshiftdiffusionv1'      #Model 3:edshift diffusion v1
#chooseModel='modf222'                  #Model 4:f222
#chooseModel='insins'                   #model 5:ins写真风
#chooseModel='attractivewomen-attrmixv2'#model 6:attractive women
#chooseModel='tofumix'                  #model 7:tofumix 
#chooseModel='elldrethsretromix'        #model 8:elldrethsretromix 
#chooseModel='hassanblend1-4pruned'     #model 9:Hassan blend 1.4 pruned 
#chooseModel='hassanblend1512pruned'    #model 10:Hassan blend 1.5.1.2 pruned
#chooseModel='hassanblend1512full'      #model 11:Hassan blend 1.5.1.2 full
#chooseModel='clarity14'                #model 12:clarity1.4
#chooseModel='visiongenrealism-v10'     #model 13:Visiongen Realism-v1.0
#chooseModel='basilticabyssdream-bad03ver1vae' #model 14:basilticabyss dream
#chooseModel ='basil-mix-fixed'         #model 14:basil-mix-fixed

#inpainting
#chooseModel='inpainting'               #Model 1:stable diffusion 1.5 inpainting
#chooseModel='clarityinpainting'        #Model 2:clarity inpainting
#chooseModel='anythinginpainting'       #Model 3:anything inpainting

miniModels= ['momoko','animefullfinalpruned','redshiftdiffusionv1','mignon','nicenice','insins','gamecg-9702','attractivewomen-attrmixv2','tofumix','hassanblend1-4pruned','hassanblend1512pruned','clarityinpainting','clarity14','basilticabyssdream-bad03ver1vae','gfstyle2','basil-mix-fixed']
if chooseModel in miniModels:
    try:
        shutil.copytree('/kaggle/input/tagcomplete3w2cn/wd14-tagger/wd14-tagger','/kaggle/working/stable-diffusion-webui/extensions/wd14-tagger')
    except:
        pass
else:
    try:
        shutil.rmtree('/kaggle/working/stable-diffusion-webui/extensions/wd14-tagger/')
    except:
        pass
ChangeModel(chooseModel)
print('模型已切换成：'+chooseModel)
# Out:
# 模型已切换成：anythingv3

# %%
#启动webui
# %cd /kaggle/working/stable-diffusion-webui
# hacks to load model in kaggle
# !sed -i 's/map_location="cpu"/map_location="cuda"/g' /kaggle/working/stable-diffusion-webui/modules/sd_models.py
import gc
gc.collect()
#  use normal stable-diffusion
# !COMMANDLINE_ARGS="--share --config config.yaml --disable-safe-unpickle --api --cors-allow-origins=https://www.painthua.com" REQS_FILE="requirements.txt" python launch.py
# Out:
# /kaggle/working/stable-diffusion-webui
# Python 3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53)
# [GCC 9.4.0]
# Commit hash: <none>
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# No module 'xformers'. Proceeding without it.
#
# Launching Web UI with arguments: --share --config config.yaml --disable-safe-unpickle --api --cors-allow-origins=https://www.painthua.com
# No module 'xformers'. Proceeding without it.
# ...
# You are running torch 1.11.0.
# The program is tested to work with torch 1.13.1.
# To reinstall the desired version, run with commandline flag --reinstall-torch.
# ...

# %% [markdown]
# # ******negative prompt: lowres, bad anatomy, bad hands, text, error, missing fingers, extra digit, fewer digits, cropped, worst quality, low quality, normal quality, jpeg artifacts, signature, watermark, username, blurry, bad feet**

# %%
# Pack images to output.zip. You can then download it at "Data-Output" area. 将图片打包复制出来，便于保存
# !zip -q -r output.zip /kaggle/working/stable-diffusion-webui/outputs 
# !mv /kaggle/working/stable-diffusion-webui/output.zip /kaggle/working/output.zip

import os
os.chdir('/kaggle/working')
from IPython.display import FileLink
FileLink('output.zip')

# %% [markdown]
# * # The following codes are for training 以下代码训练时用

# %%
#训练前修改vae文件
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest1.vae.pt 
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned1.vae.pt
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.01.vae.pt
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.01.vae.pt

with open ('/kaggle/working/stable-diffusion-webui/config.json','r') as f:
    cc = f.read()
cc = cc.replace('"sd_vae": "auto"','"sd_vae": "None"')
with open ('/kaggle/working/stable-diffusion-webui/config.json','w') as f:
    f.write(cc)

# %%
#训练后改回vae文件
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest1.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.vae.pt 
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned1.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.vae.pt
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.01.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt
#!mv /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.01.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko/momoko-any3.0.vae.pt

with open ('/kaggle/working/stable-diffusion-webui/config.json','r') as f:
    cc = f.read()
cc = cc.replace('"sd_vae": "None"','"sd_vae": "auto"')
with open ('/kaggle/working/stable-diffusion-webui/config.json','w') as f:
    f.write(cc)

# %%
#copy the pt file for saving 将训练好的模型复制出来，便于保存
# !cp -r /kaggle/working/stable-diffusion-webui/embeddings/ZYX13.pt /kaggle/working/ZYX13.pt    #将ZYX13.pt修改为你训练好的pt文件名

import os
os.chdir('/kaggle/working/stable-diffusion-webui/embeddings/')
from IPython.display import FileLink
FileLink('ZYX13.pt')

# %%
# !cp -r /kaggle/working/stable-diffusion-webui/ui-config.json /kaggle/working/ui-config.json
# !cp -r /kaggle/working/stable-diffusion-webui/config.json /kaggle/working/config.json
# !cp -r /kaggle/working/stable-diffusion-webui/styles.csv /kaggle/working/styles.csv

import os
os.chdir('/kaggle/working/stable-diffusion-webui/')
from IPython.display import FileLink
FileLink('ui-config.json')
FileLink('config.json')
FileLink('styles.csv')

# %% [markdown]
# # 废弃代码

# %%
#废弃代码

#%cd /kaggle/working/stable-diffusion-webui
#!git clone "https://github.com/DominikDoom/a1111-sd-webui-tagcomplete.git" extensions/tag-autocomplete
#!git clone https://github.com/d8ahazard/sd_dreambooth_extension extensions/dreambooth

#%cd /kaggle/working/stable-diffusion-webui
#!git clone https://github.com/KichangKim/DeepDanbooru

#os.listdir('/kaggle/working/stable-diffusion-webui/DeepDanbooru')
#%cd /kaggle/working/stable-diffusion-webui/DeepDanbooru
#!pip install -r requirements.txt

# %%
#旧版更换模型方法，非必要不使用

import re
import os

def ChangeModel2(modelPath):
    with open ('/kaggle/working/stable-diffusion-webui/modules/sd_models.py','r') as f:
        tt = f.read()
    tt = re.sub('model_dir = ".*?"','model_dir = "{}"'.format(modelPath),tt)
    with open ('/kaggle/working/stable-diffusion-webui/modules/sd_models.py','w') as f:
        f.write(tt)
        
import os
sdfiles = os.listdir('/kaggle/working/stable-diffusion-webui/models/Stable-diffusion/')
ckptfile = '/kaggle/working/stable-diffusion-webui/models/Stable-diffusion/'
for f in sdfiles:
    if '.ckpt' in f:
        ckptfile = ckptfile+f
try:
    os.remove(ckptfile)
except:
    pass

#ChangeModel2('Stable-diffusion')
#Select the model you like根据喜好选择模型
#Remove the # signal before the code if you want to run the model, and add the # symbol before the other
#在你想要使用的模型对应的代码前去掉#，其他模型的对应代码前加上#

#Model 1 (default) ： 7g animefull-final-latest
# 二次元和写实风兼有
#cp -r /kaggle/input/animefulllatestckpt/animefull-latest.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.ckpt
#cp -r /kaggle/input/animefulllatestckpt/animefull-latest.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-latest.vae.pt

#Model 2: 4g animefull-final-pruned
# 二次元风格
#!cp -r /kaggle/input/nai-pruned/animefull-final-pruned.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/animefull-final-pruned.ckpt

#Model 3: 7g stable-diffusion-1.5
#写实风
#!cp -r /kaggle/input/stable-diffusion-1-5/v1-5-pruned.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/sd15-pruned.ckpt

#Model 4:7g Anything-v3.0
#Novel AI最新模型
#!cp -r /kaggle/input/anythingv3/Anything-V3.0.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.ckpt
#!cp -r /kaggle/input/anythingv3/Anything-V3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/Anything-V3.0.vae.pt

#Model 5:stable diffusion 1.5 inpainting
#专用于inpaint的模型
#!cp -r /kaggle/input/inpainting/sd-v1-5-inpainting.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/sd-v1-5-inpainting.ckpt

#Model 6:7g momoko-Anything-v3.0
#看标题像momoko，哪位大哥测试一下效果？
#!cp -r /kaggle/input/momoko/momoko-any3.0.ckpt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.ckpt
#!cp -r /kaggle/input/momoko/momoko-any3.0.vae.pt /kaggle/working/stable-diffusion-webui/models/Stable-diffusion/momoko-any3.0.vae.pt

# %%
#%cd /kaggle/working/
#!zip -q -r web.zip /kaggle/working/stable-diffusion-webui

# %%
# #%cd stable-diffusion-webui
# !git pull

# #@title Install Bore Tunnel
# !wget https://github.com/ekzhang/bore/releases/download/v0.4.0/bore-v0.4.0-x86_64-unknown-linux-musl.tar.gz
# !tar -xf bore-v0.4.0-x86_64-unknown-linux-musl.tar.gz
# !rm -f bore-v0.4.0-x86_64-unknown-linux-musl.tar.gz
# !cp bore /usr/bin/bore
# !rm -rf bore

#!COMMANDLINE_ARGS="--exit" REQS_FILE="requirements.txt" python launch.py

# #!sed -i -e "125 c \ \ \ \ sd = pl_sd" /content/stable-diffusion-webui/modules/sd_models.py      #if use 7G version, turn this on.  
# !python webui.py --autolaunch --disable-safe-unpickle --precision autocast --config config.yaml & bore local 7860 --to bore.pub
